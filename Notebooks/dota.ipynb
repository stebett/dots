# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('/home/ginko/Documents/projects/dota/data/train_features.csv')

# %%
data.sample(5)
# Out:
#                           match_id_hash  game_time  game_mode  lobby_type  \
# 30997  0ad247328a0fd98aae921f36533b17e6        736         22           7
# 32050  bd0d4f196247f50d6b1e329bfe4c492a       1772         22           7
# 29409  44266ed02a5afdfe1ca28026b8f5882a       1588         22           7
# 19153  2a9e7a53f49533e6e28a460600ccc967        564         22           7
# 30677  bee797c3ca9ccfba3b2eec83da987047        274         22           7
#
#        objectives_len  chat_len  r1_hero_id  r1_kills  r1_deaths  r1_assists  \
# 30997               3         0           7         1          1           1
# 32050              14         2          30         9          6          18
# 29409               5        59          17        12          3           4
# 19153               1        12           8         3          2           0
# 30677               1         3          50         0          1           3
#
# ...

# %%
data.describe()
# Out:
#           game_time     game_mode    lobby_type  objectives_len      chat_len  \
# count  39675.000000  39675.000000  39675.000000    39675.000000  39675.000000
# mean    1146.082798     19.584776      4.772350        6.524865      7.338500
# std      767.206621      6.304976      3.260582        6.492107     13.366381
# min        0.000000      2.000000      0.000000        0.000000      0.000000
# 25%      521.000000     22.000000      0.000000        1.000000      0.000000
# 50%     1044.000000     22.000000      7.000000        4.000000      3.000000
# 75%     1656.000000     22.000000      7.000000       10.000000      9.000000
# max     4933.000000     23.000000      7.000000       43.000000    291.000000
#
#          r1_hero_id      r1_kills     r1_deaths    r1_assists     r1_denies  \
# count  39675.000000  39675.000000  39675.000000  39675.000000  39675.000000
# mean      51.103138      3.147876      3.268809      4.670170      6.289628
# ...

# %%
data.loc[data['r1_hero_id'] == 3].describe()
# Out:
#          game_time   game_mode  lobby_type  objectives_len    chat_len  \
# count   218.000000  218.000000  218.000000      218.000000  218.000000
# mean   1151.449541   18.821101    5.233945        6.302752    8.311927
# std     689.940630    7.006259    3.047299        5.845168   16.329667
# min       8.000000    2.000000    0.000000        0.000000    0.000000
# 25%     581.500000   22.000000    1.750000        1.000000    0.000000
# 50%    1122.000000   22.000000    7.000000        5.000000    3.000000
# 75%    1629.000000   22.000000    7.000000       10.000000   10.000000
# max    2898.000000   23.000000    7.000000       24.000000  132.000000
#
#        r1_hero_id    r1_kills   r1_deaths  r1_assists   r1_denies  \
# count       218.0  218.000000  218.000000  218.000000  218.000000
# mean          3.0    2.321101    3.247706    5.247706    3.729358
# std           0.0    2.250983    3.115757    4.925540    4.827452
# ...
